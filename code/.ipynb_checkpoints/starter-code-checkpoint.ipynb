# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# two data set are given that we have to develop further analysis into Traffic and licenses.

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# we are given a two data sets that we have to develop further analysis into Traffic and licenses. Traffic contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016 and 2017.licenses contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993–2016 by General Authority for Statistics as well.
#
# Data Import and Cleaning
# First of all, i notice that data needs a cleaning where data should be clear and readable  to Data Scientists before the reader. For instance taking off repetitive columns, unnecessary information, and Null values above picture is an example of unclean.
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning
#
# Visualize the data
# refers to the techniques used to communicate data or information by encoding it as visual objects (e.g., points, lines or bars) contained in graphics.

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# Lines below are just to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#importing datas 

traffic = pd.read_csv("/Users/faisalshuraym/Desktop/Data_Scince_GA/GA_Projects/project-1/data/saudi-arabia-traffic-accidents-2008.csv", sep=';') 
licenses = pd.read_csv("/Users/faisalshuraym/Desktop/Data_Scince_GA/GA_Projects/project-1/data/saudi-arabia-driving-licenses-2004-2008.csv",sep=';')
traffic.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year          Region  \
# 0           0             0  (2016)          Makkah
# 1           1             1  (2016)  Eastern Region
# 2           2             2  (2016)          Tabouk
# 3           3             3  (2016)            Hail
# 4           4             4  (2016)            Hail
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# 4             No. of Accidents  10199n   27.400845724, 41.4406960508

# %%
# dropping duplicate columns 
licenses.drop(['Unnamed: 0'], axis=1, inplace = True)
traffic.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1, inplace = True)

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
# checking the head
traffic.head(10)
# Out:
#      Year            Region                    Indicator   Value  \
# 0  (2016)            Makkah  No. of Casualties - Injured  12383n
# 1  (2016)    Eastern Region     No. of Casualties - Dead   1113n
# 2  (2016)            Tabouk     No. of Casualties - Dead    434n
# 3  (2016)              Hail     No. of Casualties - Dead    299n
# 4  (2016)              Hail             No. of Accidents  10199n
# 5  (2016)  Northern Boarder     No. of Casualties - Dead    193n
# 6  (2017)             Jazan             No. of Accidents  22161n
# 7  (2017)           Al-Jouf             No. of Accidents  10469n
# 8  (2017)             Total     No. of Casualties - Dead   7489n
# 9  (2016)  Northern Boarder  No. of Casualties - Injured    631n
#
#                    geo_point_2d
# 0   21.628962766, 41.2636898334
# 1  23.2883307307, 50.1478302439
# 2    27.90165499, 37.2598581394
# 3   27.400845724, 41.4406960508
# 4   27.400845724, 41.4406960508
# 5   30.197074783, 41.8171186952
# ...

# %%
# checking the head
licenses.head(10)
# Out:
#      Year Administritive Area Driving Liceses                 geo_point_2d
# 0  (2012)              Makkah         143954n  21.628962766, 41.2636898334
# 1  (1994)              Makkah          75349n  21.628962766, 41.2636898334
# 2  (1998)              Makkah          86082n  21.628962766, 41.2636898334
# 3  (2004)              Makkah          86636n  21.628962766, 41.2636898334
# 4  (2005)              Makkah          65099n  21.628962766, 41.2636898334
# 5  (2008)              Makkah          77013n  21.628962766, 41.2636898334
# 6  (2014)             Madinah          31447n  24.927534539, 39.4918237173
# 7  (2013)             Madinah          28513n  24.927534539, 39.4918237173
# 8  (2012)             Madinah          14459n  24.927534539, 39.4918237173
# 9  (1994)             Madinah           3767n  24.927534539, 39.4918237173

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# Answer: Data has some repetitive columns such as Unnamed 0 ,and Unnamed 1. it also have n in Value columns and some missing values in Geo_point_2d

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
#Code we 6 missing data in geo_point_2d
traffic.isnull().sum()
# Out:
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
# counting missing value in Licenses
licenses.isnull().sum()
# Out:
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
# Data 1
traffic.min()
# Out:
# Year                   (2016)
# Region               Al-Baaha
# Indicator    No. of Accidents
# Value                   1007n
# dtype: object

# %%
# finding the max 
traffic.max()
# Out:
# Year                              (2017)
# Region                             Total
# Indicator    No. of Casualties - Injured
# Value                             99925n
# dtype: object

# %%
licenses.min()
# Out:
# Year                    (1993)
# Administritive Area    Al-Baha
# Driving Liceses        100291n
# dtype: object

# %%
# Finding the min 
licenses.max()
# Out:
# Year                   (2017)
# Administritive Area     Total
# Driving Liceses         9983n
# dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#finding out types
traffic.dtypes
# Out:
# Year            object
# Region          object
# Indicator       object
# Value           object
# geo_point_2d    object
# dtype: object

# %%
# getting more insight about data 
licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 4 columns):
# Year                   350 non-null object
# Administritive Area    350 non-null object
# Driving Liceses        350 non-null object
# geo_point_2d           325 non-null object
# dtypes: object(4)
# memory usage: 11.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: geo_point_2d    78 non-null object is clearly missing  some values

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
# taking out the pranthesis from data 
traffic.Year= traffic.Year.apply(lambda x: x.replace('(', ''))
traffic.Year= traffic.Year.apply(lambda x: x.replace(')', ''))

# %%
traffic.head(1)
# Out:
#    Year  Region                    Indicator   Value  \
# 0  2016  Makkah  No. of Casualties - Injured  12383n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334

# %%
traffic.head()
# Out:
#    Year          Region                    Indicator   Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383n
# 1  2016  Eastern Region     No. of Casualties - Dead   1113n
# 2  2016          Tabouk     No. of Casualties - Dead    434n
# 3  2016            Hail     No. of Casualties - Dead    299n
# 4  2016            Hail             No. of Accidents  10199n
#
#                    geo_point_2d
# 0   21.628962766, 41.2636898334
# 1  23.2883307307, 50.1478302439
# 2    27.90165499, 37.2598581394
# 3   27.400845724, 41.4406960508
# 4   27.400845724, 41.4406960508

# %%
traffic.shape
# Out:
# (84, 5)

# %%
traffic.head(2)
# Out:
#    Year          Region                    Indicator   Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383n
# 1  2016  Eastern Region     No. of Casualties - Dead   1113n
#
#                    geo_point_2d
# 0   21.628962766, 41.2636898334
# 1  23.2883307307, 50.1478302439

# %%
# taking out the pranthesis from data2
licenses.Year= licenses.Year.apply(lambda x: x.replace('(', ''))
licenses.Year= licenses.Year.apply(lambda x: x.replace(')', ''))

# %%
# taking out 'n' from Driving Liceses' data2
licenses['Driving Liceses']= licenses['Driving Liceses'].apply(lambda x: x.replace('n',''))

# %%
# takingout 'n' from Value data 
traffic.Value= traffic.Value.apply(lambda x: x.replace('n',''))

# %%
#change year,and Value to type int data
traffic[['Year', 'Value']] = traffic[['Year', 'Value']].apply(pd.to_numeric)

# %%
# code change year,and Value to type int data
licenses[['Year','Driving Liceses']] = licenses[['Year','Driving Liceses']].apply(pd.to_numeric)

# %%
# split GEO point colums for data
new= traffic.geo_point_2d.str.split(",",expand=True)
traffic['x'] = new[0]
traffic['y']= new[1]

# %%
new= traffic.geo_point_2d.str.split(",",expand=True)

# %%
#split GEo 
newData2 = licenses.geo_point_2d.str.split(",",expand=True)
licenses['x']= newData2[0]
licenses['y']= newData2[1]

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code Already done

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# checking weather my data changed 
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
# Year            84 non-null int64
# Region          84 non-null object
# Indicator       84 non-null object
# Value           84 non-null int64
# geo_point_2d    78 non-null object
# x               78 non-null object
# y               78 non-null object
# dtypes: int64(2), object(5)
# memory usage: 4.7+ KB

# %%
licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
# Year                   350 non-null int64
# Administritive Area    350 non-null object
# Driving Liceses        350 non-null int64
# geo_point_2d           325 non-null object
# x                      325 non-null object
# y                      325 non-null object
# dtypes: int64(2), object(4)
# memory usage: 16.5+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code: Already Done last step 
traffic.head()
# Out:
#    Year          Region                    Indicator  Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#                    geo_point_2d              x               y
# 0   21.628962766, 41.2636898334   21.628962766   41.2636898334
# 1  23.2883307307, 50.1478302439  23.2883307307   50.1478302439
# 2    27.90165499, 37.2598581394    27.90165499   37.2598581394
# 3   27.400845724, 41.4406960508   27.400845724   41.4406960508
# 4   27.400845724, 41.4406960508   27.400845724   41.4406960508

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
# Rename columns 
traffic.rename(columns={
                       'Year':'year',
                       'Region':'region' ,     
                       'Indicator':'traffic_accidents_indicator',   
                       'Value':'traffic_accidents_value', 
                        'geo_point_2d':'Geo_point',
                       'x'    :'geopoint_x' ,       
                       'y'    :'geopoint_y',
                         }, inplace=True)

# %%
# Rename columns 
licenses.rename(columns={
                        'Year':'year',
                        'Administritive Area':'region' ,     
                        'Driving Liceses':'driving_licenses_issues',
                        'geo_point_2d':'Geo_point',
                        'x'    :'geopoint_x' ,       
                        'y'    :'geopoint_y',
                        }, inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# ## Traffic dictionary
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**year**|*integer*|Traffic_Accidents|this column contains the year at which the accidents data were collected for the traffic accidents dataset (tra).|
# |**region**|*object/string*|Traffic_Accidents|this column contains the province(Administrative area) at which the accidents data were collected for the traffic accidents dataset (tra).|
# |**traffic_accidents_value**|*object/string*|Traffic_Accidents|this column contains the type of casualties for which the number is reported. we have 3 types of causualties: daed, injured or any type  of accidents were a human casualties may or may not have happened.|
# |**traffic_accidents_indicator**|*integer*|Traffic_Accidents|this column contains the number of the casualties of involved in the specified year for the specified province.|
# |**Geo_point**|*object (set of  two floats)*|Traffic_Accidents|this column contains the geografical coordinates of the privince it consist of two point coordinate, x and y for the (tra) dataset.|
# |**geopoint_x**|*float*|Traffic_Accidents|the x coordinate of the province geo coordinate set. splitted from the geo_coordinates_tra column|
# |**geopoint_y**|*float*|Traffic_Accidents|the y coordinate of the province geo coordinate set. splitted from the geo_coordinates_tra column|

# %% [markdown]
# ##  Licenses dictionary
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**year**|*integer*|Driving_Licenses|this column contains the year at which the licenses data were collected for the driving license dataset (lic).|
# |**region**|*object/string*|Driving_Licenses|the province(Administrative area) at which the driving licenses data were collected for the driving licenses dataset (lic).|
# |**driving_licenses_issues**|*integer*|Driving_Licenses|the number of the driving licenses issued in the specified year for the specified province.|
# |**Geo_point**|*object (set of  two floats)*|Driving_Licenses|this column contains the geografical coordinates of the privince it consist of two point coordinate, x and y for the (lic) dataset.|
# |**geopoint_x**|*float*|Driving_Licenses|the x coordinate of the province geo coordinate set. splitted from the geo_coordinates_lic column|
# |**geopoint_y**|*float*|Driving_Licenses|the y coordinate of the province geo coordinate set. splitted from the geo_coordinates_lic column|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
# checking how many total do i have 
traffic.loc[traffic['region'] == 'Total']
# Out:
#     year region  traffic_accidents_indicator  traffic_accidents_value  \
# 8   2017  Total     No. of Casualties - Dead                     7489
# 29  2016  Total             No. of Accidents                   533380
# 30  2016  Total  No. of Casualties - Injured                    38120
# 68  2017  Total             No. of Accidents                   460488
# 69  2017  Total  No. of Casualties - Injured                    33199
# 77  2016  Total     No. of Casualties - Dead                     9031
#
#    Geo_point geopoint_x geopoint_y
# 8        NaN        NaN        NaN
# 29       NaN        NaN        NaN
# 30       NaN        NaN        NaN
# 68       NaN        NaN        NaN
# 69       NaN        NaN        NaN
# 77       NaN        NaN        NaN

# %%
#performing masking
traffic= traffic[traffic['region'] != 'Total']

# %%
traffic.shape
# Out:
# (78, 7)

# %%
#checking the shape 
traffic.shape
# Out:
# (78, 7)

# %%
# checking how mant total do i have 
licenses.loc[licenses['region'] == 'Total']
# Out:
#      year region  driving_licenses_issues Geo_point geopoint_x geopoint_y
# 58   2015  Total                   435439       NaN        NaN        NaN
# 59   2017  Total                   928165       NaN        NaN        NaN
# 60   1993  Total                   294893       NaN        NaN        NaN
# 61   1994  Total                   303520       NaN        NaN        NaN
# 62   2003  Total                   254858       NaN        NaN        NaN
# 63   2006  Total                   267508       NaN        NaN        NaN
# 142  2014  Total                   625414       NaN        NaN        NaN
# 143  2010  Total                   386510       NaN        NaN        NaN
# 144  2012  Total                   411204       NaN        NaN        NaN
# 145  1999  Total                   332210       NaN        NaN        NaN
# 146  2002  Total                   282038       NaN        NaN        NaN
# 147  2001  Total                   264725       NaN        NaN        NaN
# ...

# %%
#checking the shape weather masking was performed sucssfully 
licenses.shape
# Out:
# (350, 6)

# %%
# performing masking 
licenses = licenses[licenses['region'] != 'Total']

# %%
# checking the sape 
licenses.shape
# Out:
# (325, 6)

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?
# Answer: wide is the data on horizantal and long data on vertical

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
# pivot table to reshape my data 
traffic = pd.pivot_table(traffic, values ='traffic_accidents_value', index =['year', 'region','Geo_point','geopoint_x','geopoint_y'], 
                         columns =['traffic_accidents_indicator']).reset_index()

# %%
# modify the spellig for both datasets in order to do the merge 
licenses.replace(to_replace ="Al-Qaseem", value ="Qassim", inplace = True)

# %%
licenses.replace(to_replace ="Eastern", value ="Eastern Region", inplace = True)

# %%
traffic.replace(to_replace ="A", value ="Jazan", inplace = True)
traffic.replace(to_replace ="Al-Baaha", value = "Al-Baha", inplace=True )
traffic.replace(to_replace = "Asir", value = "Assir", inplace = True )
traffic.replace(to_replace = "Makkah", value = "Makkah", inplace = True )

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
# merge two datasets into one dataset
merge_data= pd.merge(traffic, licenses, on=['region','year','Geo_point','geopoint_x','geopoint_y'], how='outer')

# %%
#displaying both datasets 
merge_data.head(50)
# Out:
#     year            region                     Geo_point     geopoint_x  \
# 0   2016           Al-Baha  20.1484058503, 41.4665484892  20.1484058503
# 1   2016           Al-Jouf  29.9677445762, 39.5570371172  29.9677445762
# 2   2016             Assir   19.1387847401, 42.941470036  19.1387847401
# 3   2016    Eastern Region  23.2883307307, 50.1478302439  23.2883307307
# 4   2016              Hail   27.400845724, 41.4406960508   27.400845724
# 5   2016             Jazan  17.2072313962, 42.6525807422  17.2072313962
# 6   2016           Madinah   24.927534539, 39.4918237173   24.927534539
# 7   2016            Makkah   21.628962766, 41.2636898334   21.628962766
# 8   2016            Najran  18.4511003068, 46.8688495726  18.4511003068
# 9   2016  Northern Boarder   30.197074783, 41.8171186952   30.197074783
# 10  2016            Qassim  26.1967063704, 43.3429998455  26.1967063704
# 11  2016            Riyadh  23.0814341634, 45.5857512766  23.0814341634
# ...

# %%
# get the shape 
merge_data.shape
# Out:
# (325, 9)

# %%
# displaying data types
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 324
# Data columns (total 9 columns):
# year                           325 non-null int64
# region                         325 non-null object
# Geo_point                      325 non-null object
# geopoint_x                     325 non-null object
# geopoint_y                     325 non-null object
# No. of Accidents               26 non-null float64
# No. of Casualties - Dead       26 non-null float64
# No. of Casualties - Injured    26 non-null float64
# driving_licenses_issues        325 non-null int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 25.4+ KB

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
#save both datasets into one one file called combined_datasets
merge_data.to_csv('combined_datasets.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# should have modified while ago but just find out i did not 
merge_data.geopoint_y = merge_data.geopoint_y.apply(lambda x :eval(x))
merge_data.geopoint_x = merge_data.geopoint_x.apply(lambda x :eval(x))

# %%
# basic EDA
merge_data.describe().transpose()
# Out:
#                              count          mean           std          min  \
# year                         325.0   2005.000000      7.222222  1993.000000
# geopoint_x                   325.0     23.810447      4.197987    17.207231
# geopoint_y                   325.0     42.602789      3.254196    37.259858
# No. of Accidents              26.0  38225.692308  46493.705035  1414.000000
# No. of Casualties - Dead      26.0    635.384615    549.783381   112.000000
# No. of Casualties - Injured   26.0   2743.038462   2922.641127   374.000000
# driving_licenses_issues      325.0  28915.347692  47419.058819   915.000000
#
#                                       25%           50%           75%  \
# year                          1999.000000   2005.000000   2011.000000
# geopoint_x                      20.148406     23.288331     27.400846
# geopoint_y                      41.263690     41.817119     43.343000
# No. of Accidents             10276.250000  16050.500000  30981.250000
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
# calculating stander deviation 
# i calcualte  n-1 as  what np does  
import math 

# calculating the std
def std(Series):
    col = Series.dropna()
    s = list(Series)
    
    length= (Series.count())  # n 
    mean= Series.sum()/(Series.count()) # calc mean 
    total_sum = 0 
    
    for i in range(length):
        total_sum+= (s[i]- mean)**2  # x - mean ^2
    under_root= total_sum/length  # total sum (x -x~)/ length (n-1).squart
    return  math.sqrt(under_root)

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %%
# writing a new dataframe for numeric 
numeric = merge_data[['year','No. of Casualties - Dead', 'No. of Casualties - Injured', 
    'No. of Accidents', 'driving_licenses_issues','geopoint_x','geopoint_y']]

# %%
# dictionary comperhension
{i : std(numeric[i]) for i in numeric}
# Out:
# {'year': 7.211102550927978,
#  'No. of Casualties - Dead': 539.1069593406002,
#  'No. of Casualties - Injured': 2865.885411322023,
#  'No. of Accidents': 45590.82869880505,
#  'driving_licenses_issues': 47346.05021744638,
#  'geopoint_x': 4.191524025811858,
#  'geopoint_y': 3.249185305131691}

# %%
# compare it with numpy 
{i : np.std(numeric[i]) for i in numeric}
# Out:
# {'year': 7.211102550927978,
#  'No. of Casualties - Dead': 539.1069593406002,
#  'No. of Casualties - Injured': 2865.885411322023,
#  'No. of Accidents': 45590.82869880505,
#  'driving_licenses_issues': 47346.05021744638,
#  'geopoint_x': 4.1915240258118605,
#  'geopoint_y': 3.249185305131692}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: with pandas poplulation - the sample and my function calcualte population

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Which regions have the highest Driving Licenses based on years (1993 - 2017) 
merge_data.nlargest(5,"driving_licenses_issues")[['region',"driving_licenses_issues"]]
# Out:
#      region  driving_licenses_issues
# 24   Riyadh                   495307
# 11   Riyadh                   242851
# 158  Riyadh                   194208
# 82   Riyadh                   165994
# 85   Makkah                   157389

# %%
merge_data
# Out:
#      year            region                     Geo_point  geopoint_x  \
# 0    2016           Al-Baha  20.1484058503, 41.4665484892   20.148406
# 1    2016           Al-Jouf  29.9677445762, 39.5570371172   29.967745
# 2    2016             Assir   19.1387847401, 42.941470036   19.138785
# 3    2016    Eastern Region  23.2883307307, 50.1478302439   23.288331
# 4    2016              Hail   27.400845724, 41.4406960508   27.400846
# 5    2016             Jazan  17.2072313962, 42.6525807422   17.207231
# 6    2016           Madinah   24.927534539, 39.4918237173   24.927535
# 7    2016            Makkah   21.628962766, 41.2636898334   21.628963
# 8    2016            Najran  18.4511003068, 46.8688495726   18.451100
# 9    2016  Northern Boarder   30.197074783, 41.8171186952   30.197075
# 10   2016            Qassim  26.1967063704, 43.3429998455   26.196706
# 11   2016            Riyadh  23.0814341634, 45.5857512766   23.081434
# ...

# %%
#Which regions have the smallest Driving Licenses based on years (1993 - 2017) 
merge_data.nsmallest(5,"driving_licenses_issues")[['region',"driving_licenses_issues"]]
# Out:
#                region  driving_licenses_issues
# 205            Tabouk                      915
# 177           Al-Baha                      997
# 266  Northern Boarder                     1318
# 164  Northern Boarder                     1383
# 267  Northern Boarder                     1457

# %%
#Which regions have the highest mean Traffic Accidents numbers for years (2016 - 2017)
by_mean = merge_data.groupby(['year','region']).mean()

# %%
by_mean.nlargest(3,'No. of Accidents') [['No. of Accidents']]
# Out:
#              No. of Accidents
# year region
# 2017 Makkah          145541.0
# 2016 Riyadh          141736.0
#      Makkah          134838.0

# %%
# #Which regions have the lowest mean Traffic Accidents numbers for years (2016 - 2017)
by_mean.nsmallest(3,'No. of Accidents')[['No. of Accidents']]
# Out:
#               No. of Accidents
# year region
# 2017 Al-Baha            1414.0
#      Najran             3193.0
# 2016 Najran             3235.0

# %%
#What are the regions that have more Driving Licenses issued in each year 
#than the year average?
by_the_mean = merge_data.groupby(['year']).mean()[['driving_licenses_issues']]# including the driving licten 
by_the_mean
# Out:
#       driving_licenses_issues
# year
# 1993             22684.076923
# 1994             23347.692308
# 1995             19375.230769
# 1996             18278.692308
# 1997             22253.538462
# 1998             26026.923077
# 1999             25554.615385
# 2000             21018.307692
# 2001             20363.461538
# 2002             21695.230769
# 2003             19604.461538
# 2004             20672.153846
# 2005             19323.307692
# 2006             20577.538462
# 2007             25488.923077
# 2008             25396.769231
# 2009             28944.230769
# 2010             29731.538462
# 2011             30812.153846
# 2012             31631.076923
# 2013             43485.692308
# 2014             48108.769231
# 2015             33495.307692
# 2016             53616.692308
# 2017             71397.307692

# %%
df= pd.merge(by_the_mean,merge_data,on=['year'],how='outer')
df= df[df['driving_licenses_issues_y']> df.driving_licenses_issues_x][['year','driving_licenses_issues_y','region']]
df.sort_values('year')
# Out:
#      year  driving_licenses_issues_y          region
# 3    1993                     103886          Riyadh
# 4    1993                      65977          Makkah
# 10   1993                      73618          Qassim
# 13   1994                      75349          Makkah
# 16   1994                      68916          Qassim
# 20   1994                     110545          Riyadh
# 26   1995                      49690          Qassim
# 32   1995                     101608          Riyadh
# 33   1995                      60356          Makkah
# 39   1996                      42693          Qassim
# 45   1996                     110131          Riyadh
# 51   1996                      46195          Makkah
# 53   1997                      92145          Riyadh
# 54   1997                      76623          Makkah
# 60   1997                      58814  Eastern Region
# 74   1998                     114962          Riyadh
# 77   1998                      70650  Eastern Region
# ...

# %%
#What are the regions that have more Traffic Accidents happened in each year than the year averby

# %%
#What are the regions that have more Traffic Accidents happened in each year than the year averby
clac_mean = merge_data.groupby(['year']).mean()[['No. of Accidents']]# including the driving licten 
dropmean= clac_mean.dropna()
dropmean
# Out:
#       No. of Accidents
# year
# 2016      41029.230769
# 2017      35422.153846

# %%
dropmean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 2016 to 2017
# Data columns (total 1 columns):
# No. of Accidents    2 non-null float64
# dtypes: float64(1)
# memory usage: 32.0 bytes

# %%
drop= pd.merge(dropmean,merge_data,on=['year'],how='outer')
df= drop[drop['No. of Accidents_y']> drop['No. of Accidents_x']][['year','No. of Accidents_y','region']]
df.sort_values('year')
# Out:
#     year  No. of Accidents_y          region
# 3   2016            101619.0  Eastern Region
# 7   2016            134838.0          Makkah
# 11  2016            141736.0          Riyadh
# 16  2017             81433.0  Eastern Region
# 20  2017            145541.0          Makkah
# 24  2017             99925.0          Riyadh

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# heat map 
corrs = merge_data.corr()
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.heatmap(corrs,annot=True) # cmap
ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=12, rotation=20)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=12, rotation=0)
ax.set_title('correlation heat map \n', fontsize=20)
# Out:
# Text(0.5, 1.0, 'correlation heat map \n')

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
# custom function to draw histograms
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15, 7)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=20) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
# function calls 
subplot_histograms(merge_data,['driving_licenses_issues','No. of Accidents'],['Driving Licenses number',' Traffic Accidents number'] ,['Licenses','Accidents'])
subplot_histograms(merge_data,['No. of Casualties - Dead' ,'No. of Casualties - Injured'],['Casualties - Dead','Casualties - Injured'],['casualties Dead','casualties injured'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
#Driving Licenses vs. Traffic Accidents for 2017
place =merge_data[merge_data['year'] == 2017][['driving_licenses_issues']]
holder =merge_data[merge_data['year'] == 2017][['No. of Accidents']]

# %%
plt.scatter(place, holder);
plt.xlabel('Driving Licenses')
plt.ylabel('Traffic Accidents')
plt.title('Driving Licenses vs. Traffic Accidents for 2017')
# Out:
# Text(0.5, 1.0, 'Driving Licenses vs. Traffic Accidents for 2017')

# %%
#Driving Licenses vs. Traffic Accidents for 2016
var = merge_data[merge_data['year'] == 2016][['driving_licenses_issues']]
var2= merge_data[merge_data['year'] == 2016][['No. of Accidents']]

# %%
plt.scatter(var, var2);
plt.xlabel('Driving Licenses')
plt.ylabel('Traffic Accidents')
plt.title('Driving Licenses vs. Traffic Accidents for 2016')
# Out:
# Text(0.5, 1.0, 'Driving Licenses vs. Traffic Accidents for 2016')

# %%
# Traffic Accidents for 2016 vs 2017
x = merge_data[merge_data['year'] == 2017] [['driving_licenses_issues','year']]
y = merge_data[merge_data['year'] == 2016] [['driving_licenses_issues','year']]

# %%
plt.scatter(x, y);
plt.xlabel('Accidents for 2016')
plt.ylabel('Accidents for 2017')
plt.title('Traffic Accidents for 2016 vs 2017')
# Out:
# Text(0.5, 1.0, 'Traffic Accidents for 2016 vs 2017')

# %%
z = merge_data[merge_data['year'] == 2017] [['No. of Accidents','year']]
z
# Out:
#     No. of Accidents  year
# 13            1414.0  2017
# 14           10469.0  2017
# 15           25245.0  2017
# 16           81433.0  2017
# 17            9379.0  2017
# 18           22161.0  2017
# 19           16070.0  2017
# 20          145541.0  2017
# 21            3193.0  2017
# 22           11540.0  2017
# 23           22405.0  2017
# 24           99925.0  2017
# 25           11713.0  2017

# %%
n = merge_data[merge_data['year'] == 2016] [['No. of Accidents','year']]
y$
# Out:
#     driving_licenses_issues  year
# 0                      4614  2016
# 1                      9371  2016
# 2                     41367  2016
# 3                    142307  2016
# 4                     54507  2016
# 5                     11504  2016
# 6                     24540  2016
# 7                    136055  2016
# 8                      2153  2016
# 9                      4958  2016
# 10                     9180  2016
# 11                   242851  2016
# 12                    13610  2016

# %%
# Driving Licenses for 2016 vs 2017
plt.scatter(z, n);
plt.xlabel('Driving Licenses for 2016')
plt.ylabel('Driving Licenses for 2017')
plt.title('Driving Licenses for 2016 Vs 2017')
# Out:
# Text(0.5, 1.0, 'Driving Licenses for 2016 Vs 2017')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code take out year and geo point 
fig = plt.figure(figsize=(20, 10)) ## (width, height) in inches -- (6.4, 4.8) is default
ax = fig.gca() # stands for Get Current Axes

sns.boxplot(data= merge_data,fliersize=5, linewidth=3, notch=False, saturation=0.5, ax=ax, palette='Accent')
plt.title('numeric variables')
plt.show()

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# i plot number of accidents and region to illustrate highest region and lowest and continue for further analysis 
plot= sns.PairGrid(merge_data, x_vars=["No. of Accidents", "No. of Casualties - Dead","No. of Casualties - Injured"],y_vars=["region"],size= 5)
plot.map(sns.scatterplot)

# %%
merge_data.head()
# Out:
#    year          region                     Geo_point  geopoint_x  geopoint_y  \
# 0  2016         Al-Baha  20.1484058503, 41.4665484892   20.148406   41.466548
# 1  2016         Al-Jouf  29.9677445762, 39.5570371172   29.967745   39.557037
# 2  2016           Assir   19.1387847401, 42.941470036   19.138785   42.941470
# 3  2016  Eastern Region  23.2883307307, 50.1478302439   23.288331   50.147830
# 4  2016            Hail   27.400845724, 41.4406960508   27.400846   41.440696
#
#    No. of Accidents  No. of Casualties - Dead  No. of Casualties - Injured  \
# 0            3618.0                     185.0                       1227.0
# 1           10212.0                     245.0                        920.0
# 2           32684.0                     983.0                       2541.0
# 3          101619.0                    1113.0                       4893.0
# 4           10199.0                     299.0                        932.0
#
#    driving_licenses_issues
# ...

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# Answers: from what i can see on the graphs there is high corrleation between some varibles according to heat map such as Number of accidents ,Number of casualties  dead, Number of causalities injured , and Driving issused with with driving lictens issues, number of acciedent,with no causality dead ,and number of accedents againe with Driving issused. as well as, skewness to the right on driving licenses issues on casualities dead and injured. outlires apperas on number trafic accidents.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: According to the visulzition it is not normally distributed. it's more skiwed to right and has outlires on some of the graphs

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: No because there is no bell shep appears on aany of the graphs above so there are not normally distributed

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code it's not counted

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Answer:

# %%
# i decide to do further analysis on northean regions because they have the lowest of all the regions

# %%
# taking copy of the original data frame 
df_further= merge_data.copy()
df_further
# Out:
#      year            region                     Geo_point  geopoint_x  \
# 0    2016           Al-Baha  20.1484058503, 41.4665484892   20.148406
# 1    2016           Al-Jouf  29.9677445762, 39.5570371172   29.967745
# 2    2016             Assir   19.1387847401, 42.941470036   19.138785
# 3    2016    Eastern Region  23.2883307307, 50.1478302439   23.288331
# 4    2016              Hail   27.400845724, 41.4406960508   27.400846
# 5    2016             Jazan  17.2072313962, 42.6525807422   17.207231
# 6    2016           Madinah   24.927534539, 39.4918237173   24.927535
# 7    2016            Makkah   21.628962766, 41.2636898334   21.628963
# 8    2016            Najran  18.4511003068, 46.8688495726   18.451100
# 9    2016  Northern Boarder   30.197074783, 41.8171186952   30.197075
# 10   2016            Qassim  26.1967063704, 43.3429998455   26.196706
# 11   2016            Riyadh  23.0814341634, 45.5857512766   23.081434
# ...

# %%
# taking specific columns 
df_research= df_further[['year','region','No. of Accidents','No. of Casualties - Dead','No. of Casualties - Injured']]

# %%
# masking through dataset 
df_research= df_research[(df_research.region == 'Al-Jouf') | (df_research.region =='Northern Boarder') | (df_research.region == 'Tabouk')|(df_research.region == 'Hail')] 
df_research
# Out:
#      year            region  No. of Accidents  No. of Casualties - Dead  \
# 1    2016           Al-Jouf           10212.0                     245.0
# 4    2016              Hail           10199.0                     299.0
# 9    2016  Northern Boarder           13196.0                     193.0
# 12   2016            Tabouk           16031.0                     434.0
# 14   2017           Al-Jouf           10469.0                     240.0
# 17   2017              Hail            9379.0                     265.0
# 22   2017  Northern Boarder           11540.0                     112.0
# 25   2017            Tabouk           11713.0                     348.0
# 47   2010            Tabouk               NaN                       NaN
# 48   2013            Tabouk               NaN                       NaN
# 49   1996            Tabouk               NaN                       NaN
# 50   1998            Tabouk               NaN                       NaN
# ...

# %%
# plot my observation on scatter plot 
plot= sns.PairGrid(df_research, x_vars=['No. of Accidents','No. of Casualties - Dead','No. of Casualties - Injured'],y_vars=['year','region'],size= 4)
plot.map(sns.scatterplot)

# %%
df_research
# Out:
#      year            region  No. of Accidents  No. of Casualties - Dead  \
# 1    2016           Al-Jouf           10212.0                     245.0
# 4    2016              Hail           10199.0                     299.0
# 9    2016  Northern Boarder           13196.0                     193.0
# 12   2016            Tabouk           16031.0                     434.0
# 14   2017           Al-Jouf           10469.0                     240.0
# 17   2017              Hail            9379.0                     265.0
# 22   2017  Northern Boarder           11540.0                     112.0
# 25   2017            Tabouk           11713.0                     348.0
# 47   2010            Tabouk               NaN                       NaN
# 48   2013            Tabouk               NaN                       NaN
# 49   1996            Tabouk               NaN                       NaN
# 50   1998            Tabouk               NaN                       NaN
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:

# %% [markdown]
# traffic accidets data set is not sufficent enough to catch a pattern  to develop futher analysis.
